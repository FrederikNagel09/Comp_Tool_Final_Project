# %% [markdown]
# ## Data Processing

# %%
mode = "small"  # options: "small", "full"
path = "data/data_subset.parquet"
num_of_samples = 100

# %run scripts/run_data_processing.py --mode {mode} --path {path} --num_of_samples {num_of_samples}
# Out:
# Starting dataset processing...
# Merged dataset completed.
# Starting data cleaning...
# Saving cleaned merged dataset to CSV...
# Cleaned merged dataset saved to CSV.
#
# Starting data chunking...
# 100%|██████████| 97/97 [00:00<00:00, 30047.82it/s]
# Data chunking completed.
# Calculating metadata and embeddings...
# Calculating metadata: 100%|██████████| 200/200 [00:00<00:00, 285.38it/s]
# Metadata calculation completed.
# Embedding: 100%|██████████| 4/4 [00:01<00:00,  3.14it/s]
# Embedding calculation completed.

# %% [markdown]
# ## Statistics

# %%
# %run scripts/run_statistics.py
# Out:
# Saved histogram in graphs/text_length_histogram.png
# Basic statistics before processing:
# shape: (9, 9)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ statistic ┆ word_coun ┆ character ┆ lexical_d ┆ … ┆ avg_word_ ┆ flesch_re ┆ gunning_f ┆ punctuat │
# │ ---       ┆ t         ┆ _count    ┆ iversity  ┆   ┆ length    ┆ ading_eas ┆ og_index  ┆ ion_rati │
# │ str       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ e         ┆ ---       ┆ o        │
# │           ┆ f64       ┆ f64       ┆ f64       ┆   ┆ f64       ┆ ---       ┆ f64       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ f64       ┆           ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ count     ┆ 492812.0  ┆ 492812.0  ┆ 492812.0  ┆ … ┆ 492812.0  ┆ 492733.0  ┆ 492777.0  ┆ 492812.0 │
# │ null_coun ┆ 0.0       ┆ 0.0       ┆ 0.0       ┆ … ┆ 0.0       ┆ 79.0      ┆ 35.0      ┆ 0.0      │
# │ t         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ mean      ┆ 397.51442 ┆ 2264.9111 ┆ 0.453411  ┆ … ┆ 4.579122  ┆ 56.853163 ┆ 12.877321 ┆ 0.02132  │
# │           ┆ 3         ┆ 08        ┆           ┆   ┆           ┆           ┆           ┆          │
# │ std       ┆ 172.44525 ┆ 997.44546 ┆ 0.09682   ┆ … ┆ 0.499088  ┆ 18.459178 ┆ 5.23411   ┆ 0.007537 │
# │           ┆ 9         ┆ 6         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ min       ┆ 0.0       ┆ 1.0       ┆ 0.0       ┆ … ┆ 0.0       ┆ -644.1803 ┆ 0.0       ┆ 0.0      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ 16        ┆           ┆          │
# │ 25%       ┆ 281.0     ┆ 1577.0    ┆ 0.389722  ┆ … ┆ 4.225403  ┆ 47.472014 ┆ 10.280995 ┆ 0.016758 │
# │ 50%       ┆ 368.0     ┆ 2101.0    ┆ 0.445     ┆ … ┆ 4.508333  ┆ 59.0875   ┆ 12.32093  ┆ 0.020062 │
# │ 75%       ┆ 478.0     ┆ 2726.0    ┆ 0.507042  ┆ … ┆ 4.856397  ┆ 68.739064 ┆ 14.789622 ┆ 0.024344 │
# │ max       ┆ 1680.0    ┆ 18322.0   ┆ 1.0       ┆ … ┆ 50.6      ┆ 118.175   ┆ 293.22090 ┆ 1.0      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 8         ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
# Label distribution before processing:
#  label  percentage
#      1       37.25
#      0       62.75
# Stacking embeddings...
# Embedding stacking: 100%|██████████| 992344/992344 [00:00<00:00, 6891811.52it/s]
# Combined feature shape: (992344, 392)
# Running PCA...
# PCA complete.
#     PC  Explained Variance (%)  Cumulative Variance (%)
# 0  PC1                    7.99                     7.99
# 1  PC2                    7.20                    15.19
# 2  PC3                    5.98                    21.17
# 3  PC4                    4.17                    25.34
# 4  PC5                    3.47                    28.82
# Saved scatter plot in graphs/embedding_pca_scatterplot.png
# Basic statistics after processing:
#           word_count  character_count  lexical_diversity  avg_sentence_length  \
# count  992344.000000    992344.000000      992344.000000        992344.000000
# mean      191.957529      1090.795002           0.562281            19.929361
# std        32.392067       205.374747           0.076969             8.991412
# min       100.000000       491.000000           0.009756             2.531250
# 25%       169.000000       945.000000           0.512563            15.846154
# 50%       192.000000      1085.000000           0.560386            18.636364
# 75%       216.000000      1235.000000           0.608696            21.888889
# max       307.000000      2351.000000           0.985816           255.000000
#
#        avg_word_length  flesch_reading_ease  gunning_fog_index  \
# count    992344.000000        992344.000000      992344.000000
# mean          4.582898            57.431313          12.634074
# std           0.501038            16.981567           4.213850
# min           2.985816          -170.027313           1.729412
# 25%           4.226519            47.791710          10.061679
# 50%           4.519737            59.578785          12.115000
# 75%           4.869863            69.248154          14.611981
# max          10.797752           106.759827         102.848579
#
#        punctuation_ratio
# count      992344.000000
# mean            0.021390
# std             0.007865
# min             0.000000
# 25%             0.016447
# 50%             0.020050
# 75%             0.024681
# max             0.193437
# Label distribution after processing:
#  label  percentage
#  False       65.33
#   True       34.67

# %% [markdown]
# ## Clustering Method

# %%
# %run scripts/run_clustering.py

# %% [markdown]
# ## LSH Method

# %%
# %run scripts/run_LSH.py

# %% [markdown]
# ## Neural Network Method

# %%
# %run scripts/run_neural_network_model_training.py
